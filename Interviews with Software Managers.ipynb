# %% [markdown]
# ## Step1: Import Required Libraries

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import os
from tqdm import tqdm
import time

# %% [markdown]
# ### step2: Copy the url from required page source where the tables need to scrap and assign it to variable.

# %%
url = 'https://devtomanager.com/interviews/'

# %% [markdown]
# ### Step 3:- Set the path to chrome driver to configure web driver to use Chrome browser.

# %%
browser = webdriver.Chrome()

# %% [markdown]
# ### Step4:- Code to open the URL

# %%
browser.get(url)

# %% [markdown]
# ### Step5:- Read the HTML from page source

# %%
html = browser.page_source
html
# Out:
# '<html lang="en-US"><head>\n        <title>\nInterviews with Software Managers | Developer to Manager\n</title>\n\n        <meta charset="utf-8">\n        <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">\n\n        <meta name="author" content="Siddhant Goel">\n        <meta name="keywords" content="career, development, engineering-management, knowledge, leadership, management, platform, software">\n\n        \n<meta name="description" content="At Developer to Manager, we regularly interview software engineering managers on how they approach management and leadership.">\n\n\n        \n<meta name="twitter:card" content="summary">\n<meta name="twitter:title" content="Interviews with Software Managers | Developer to Manager">\n<meta name="twitter:description" content="About transitioning from development to management">\n<meta name="twitter:site" content="@devtomanager">\n<meta name="twitter:image" content="https://devtomanager.com/static/images/logo-wide.png">\n\n\n        <meta property="og:url" content="https://devtomanager.com/interviews/page/1/">\n        \n<meta property="og:title" content="Interviews with Software Managers | Developer to Manager">\n<meta property="og:description" content="About transitioning from development to management">\n<meta property="og:image" content="https://devtomanager.com/static/images/logo-wide.png">\n\n\n        \n        <link rel="canonical" href="https://devtomanager.com/interviews/page/1/">\n        \n\n        <link rel="apple-touch-icon" sizes="180x180" href="/static/images/apple-touch-icon.png">\n        <link rel="icon" type="image/png" sizes="32x32" href="/static/images/favicon-32x32.png">\n        <link rel="icon" type="image/png" sizes="16x16" href="/static/images/favicon-16x16.png">\n        <link rel="manifest" href="/static/images/site.webmanifest">\n        <link rel="shortcut icon" type="image/x-icon" href="/static/images/favicon.ico">\n\n        <link rel="me" href="https://twitter.com/devtomanager">\n        <link rel="alternate" type="application/atom+xml" href="/interviews/atom.xml">\n\n        <link rel="stylesheet" type="text/css" href="/static/css/app.css">\n    </head>\n    <body class="bg-light eo-recaptcha-bound">\n        <div class="container">\n    <div class="row">\n        <div class="col border-bottom">\n            <nav class="navbar navbar-light navbar-expand-lg" role="navigation">\n                <a class="navbar-brand" href="/">\n                    <img src="/static/images/logo.png" alt="Developer to Manager" width="64" height="64">\n                </a>\n\n                <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbar-menu" aria-controls="#navbar-menu" aria-expanded="false" aria-label="Toggle navigation">\n                    <span class="navbar-toggler-icon"></span>\n                </button>\n\n                <div class="collapse navbar-collapse" id="navbar-menu">\n                    <span class="navbar-text">\n                        <a href="/">\n                            <span class="h4">Developer to Manager</span>\n                        </a>\n                    </span>\n\n                    <ul class="navbar-nav ml-auto">\n                        <li class="nav-item">\n                            <a class="nav-link" href="/interviews/">\n                                All Interviews 🎙️\n                            </a>\n                        </li>\n\n                        <li class="nav-item">\n                            <a class="nav-link" href="/blog/">\n                                Blog 📑\n                            </a>\n                        </li>\n\n                        <li class="nav-item">\n                            <a class="nav-link" href="https://liberapay.com/devtomanager/donate" target="_blank">\n                                Support us! 🙏\n                            </a>\n                        </li>\n\n                        ...

# %% [markdown]
# ### Step 6: Parse HTML code and grab tables with Beautiful Soup

# %%
soup = BeautifulSoup(html,'html.parser')
soup
# Out:
# <html lang="en-US"><head>
# <title>
# Interviews with Software Managers | Developer to Manager
# </title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Siddhant Goel" name="author"/>
# <meta content="career, development, engineering-management, knowledge, leadership, management, platform, software" name="keywords"/>
# <meta content="At Developer to Manager, we regularly interview software engineering managers on how they approach management and leadership." name="description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Interviews with Software Managers | Developer to Manager" name="twitter:title"/>
# <meta content="About transitioning from development to management" name="twitter:description"/>
# <meta content="@devtomanager" name="twitter:site"/>
# <meta content="https://devtomanager.com/static/images/logo-wide.png" name="twitter:image"/>
# <meta content="https://devtomanager.com/interviews/page/1/" property="og:url"/>
# <meta content="Interviews with Software Managers | Developer to Manager" property="og:title"/>
# <meta content="About transitioning from development to management" property="og:description"/>
# <meta content="https://devtomanager.com/static/images/logo-wide.png" property="og:image"/>
# <link href="https://devtomanager.com/interviews/page/1/" rel="canonical"/>
# <link href="/static/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/static/images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/static/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/static/images/site.webmanifest" rel="manifest"/>
# <link href="/static/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://twitter.com/devtomanager" rel="me"/>
# <link href="/interviews/atom.xml" rel="alternate" type="application/atom+xml"/>
# <link href="/static/css/app.css" rel="stylesheet" type="text/css"/>
# </head>
# <body class="bg-light eo-recaptcha-bound">
# <div class="container">
# <div class="row">
# <div class="col border-bottom">
# <nav class="navbar navbar-light navbar-expand-lg" role="navigation">
# <a class="navbar-brand" href="/">
# <img alt="Developer to Manager" height="64" src="/static/images/logo.png" width="64"/>
# </a>
# <button aria-controls="#navbar-menu" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbar-menu" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbar-menu">
# <span class="navbar-text">
# <a href="/">
# <span class="h4">Developer to Manager</span>
# </a>
# </span>
# <ul class="navbar-nav ml-auto">
# <li class="nav-item">
# <a class="nav-link" href="/interviews/">
#                                 All Interviews 🎙️
#                             </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/blog/">
#                                 Blog 📑
#                             </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://liberapay.com/devtomanager/donate" target="_blank">
#                                 Support us! 🙏
#                             </a>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#                                 More
#                             </a>
# <div class="dropdown-menu dropdown-menu-right">
# <a class="dropdown-item" href="/about/">
#                                     About
#                                 </a>
# <a class="dropdown-item" href="mailto:hello@devtomanager.com?subject=Hello!">
#                                     Contact
#                                 </a>
# <a class="dropdown-item" href="/impressum/">
#                                     Impressum
#                                 </a>
# </div>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row mb-3">
# <div class="col-sm-12 col-lg-8 offset-lg-2">
# <div class="row mt-5">
# <div class="col">
# <p class="text-right">
# <a class="text-reset font-weight-bold" href="https://devtomanager.typeform.com/to/uHf6jo" target="_blank">
#         Submit your interview
#         <i class="icon-add-circle-outline mr-1"></i>
# </a>
# </p>
# </div>
# </div>
# <div class="row mt-3">
# <div class="col">
# <h1 class="text-center">Interviews with Software Managers</h1>
# <h4 class="text-center">About transitioning from development to management</h4>
# </div>
# </div>
# <div class="row mt-5">
# <div class="col text-center">
# <span class="mr-2">
# <a class="text-reset" href="/interviews/tag/coaching/">
#         #coaching
#     </a>
# </span>
# <span class="mr-2">
# <a class="text-reset" href="/interviews/tag/frontend/">
#         #frontend
#     </a>
# </span>
# <span class="mr-2">
# <a class="text-reset" href="/interviews/tag/product/">
#         #product
#     </a>
# </span>
# <span class="mr-2">
# <a class="text-reset" href="/interviews/tag/self-taught/">
#         #self-taught
#     </a>
# </span>
# <span class="mr-2">
# <a class="text-reset" href="/interviews/tag/startup/">
#         #startup
#     </a>
# </span>
# <span class="mr-2">
# <a class="text-reset" href="/interviews/tag/web/">
#         #web
#     </a>
# </span>
# </div>
# </div>
# <div class="row mt-5">
# <div class="col">
# <div class="card bg-light border-0">
# <div class="row no-gutters">
# <div class="col-md-4 text-center">
# <a href="/interviews/aviv-ben-yosef/">
# <figure class="figure">
# <img alt="Aviv Ben-Yosef, Tech Executive Consultant" class="figure-img img-fluid img-thumbnail rounded-circle" height="200" src="/static/images/interviews/aviv-ben-yosef.png" width="200"/>
# </figure>
# </a>
# </div>
# <div class="col-md-8">
# <div class="card-body">
# <h5 class="card-title">
# <a class="text-reset" href="/interviews/aviv-ben-yosef/">
#                         Aviv Ben-Yosef, Tech Executive Consultant
#                     </a>
# </h5>
# <p class="card-text">
#                 “I want to set up managers to succeed, no matter how much background they’ve already got.”
#                 </p>
# <p class="card-text">
#                     August 16, 2021
#                     ·
#
#                     <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/coaching/">
#                             #coaching
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/consulting/">
#                             #consulting
#                         </a>
# </strong>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row mt-5">
# <div class="col">
# <div class="card bg-light border-0">
# <div class="row no-gutters">
# <div class="col-md-4 text-center">
# <a href="/interviews/anand-safi/">
# <figure class="figure">
# <img alt="Anand Safi, Engineering Manager at Mark43" class="figure-img img-fluid img-thumbnail rounded-circle" height="200" src="/static/images/interviews/anand-safi.png" width="200"/>
# </figure>
# </a>
# </div>
# <div class="col-md-8">
# <div class="card-body">
# <h5 class="card-title">
# <a class="text-reset" href="/interviews/anand-safi/">
#                         Anand Safi, Engineering Manager at Mark43
#                     </a>
# </h5>
# <p class="card-text">
#                 “I very well understand where my interests lie, which is being an enabler first and then a creator rather than being a creator/ maker 100%.”
#                 </p>
# <p class="card-text">
#                     July 19, 2021
#                     ·
#
#                     <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/coaching/">
#                             #coaching
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/frontend/">
#                             #frontend
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/full-stack/">
#                             #full-stack
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/public-safety/">
#                             #public-safety
#                         </a>
# </strong>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row mt-5">
# <div class="col">
# <div class="card bg-light border-0">
# <div class="row no-gutters">
# <div class="col-md-4 text-center">
# <a href="/interviews/shawn-axsom/">
# <figure class="figure">
# <img alt="Shawn Axsom, Senior Engineering Manager at Docker" class="figure-img img-fluid img-thumbnail rounded-circle" height="200" src="/static/images/interviews/shawn-axsom.png" width="200"/>
# </figure>
# </a>
# </div>
# <div class="col-md-8">
# <div class="card-body">
# <h5 class="card-title">
# <a class="text-reset" href="/interviews/shawn-axsom/">
#                         Shawn Axsom, Senior Engineering Manager at Docker
#                     </a>
# </h5>
# <p class="card-text">
#                 “Your focus (and challenges) grows from your direct reports, to teams, to departments, executives, and then external customers and partnerships.”
#                 </p>
# <p class="card-text">
#                     July 05, 2021
#                     ·
#
#                     <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/backend/">
#                             #backend
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/coaching/">
#                             #coaching
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/information-systems/">
#                             #information-systems
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/web/">
#                             #web
#                         </a>
# </strong>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row mt-5">
# <div class="col">
# <div class="card bg-light border-0">
# <div class="row no-gutters">
# <div class="col-md-4 text-center">
# <a href="/interviews/kevin-doyle/">
# <figure class="figure">
# <img alt="Kevin Doyle, CTO at patientMpower" class="figure-img img-fluid img-thumbnail rounded-circle" height="200" src="/static/images/interviews/kevin-doyle.png" width="200"/>
# </figure>
# </a>
# </div>
# <div class="col-md-8">
# <div class="card-body">
# <h5 class="card-title">
# <a class="text-reset" href="/interviews/kevin-doyle/">
#                         Kevin Doyle, CTO at patientMpower
#                     </a>
# </h5>
# <p class="card-text">
#                 “If I can provide enough direction to allow people to focus on the jobs they’ll do better than I ever could, everybody wins.”
#                 </p>
# <p class="card-text">
#                     June 21, 2021
#                     ·
#
#                     <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/full-stack/">
#                             #full-stack
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/health-tech/">
#                             #health-tech
#                         </a>
# </strong>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row mt-5">
# <div class="col">
# <div class="card bg-light border-0">
# <div class="row no-gutters">
# <div class="col-md-4 text-center">
# <a href="/interviews/arnab-sen/">
# <figure class="figure">
# <img alt="Arnab Sen, Technical Delivery Manager at AKQA" class="figure-img img-fluid img-thumbnail rounded-circle" height="200" src="/static/images/interviews/arnab-sen.png" width="200"/>
# </figure>
# </a>
# </div>
# <div class="col-md-8">
# <div class="card-body">
# <h5 class="card-title">
# <a class="text-reset" href="/interviews/arnab-sen/">
#                         Arnab Sen, Technical Delivery Manager at AKQA
#                     </a>
# </h5>
# <p class="card-text">
#                 “The switch to management can be highly rewarding and provide a level of independence, authority, and interactivity that a pure software engineering role may not offer.”
#                 </p>
# <p class="card-text">
#                     May 10, 2021
#                     ·
#
#                     <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/consulting/">
#                             #consulting
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/digital-marketing/">
#                             #digital-marketing
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/e-commerce/">
#                             #e-commerce
#                         </a>
# </strong>
# <strong class="mr-2">
# <a class="text-reset" href="/interviews/tag/product/">
#                             #product
#                         </a>
# </strong>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row mt-5">
# <div class="col text-left">
# </div>
# <div class="col text-right">
# <a class="text-reset font-weight-bold" href="/interviews/page/2/">
#             Older
#             <i class="icon-arrow-forward-circle-outline"></i>
# </a>
# </div>
# </div>
# <div class="row mt-5">
# <div class="col">
# <div class="row text-center">
# <div class="container">
# <div class="row">
# <div class="col">
#                 Join <mark>thousands</mark> of other subscribers receiving updates
#                 <mark>every 2 weeks</mark>!
#             </div>
# </div>
# <div class="row">
# <div class="col-6 offset-3">
# <div class="emailoctopus-form-wrapper emailoctopus-form-default null">
# <form action="https://emailoctopus.com/lists/f17f7f51-575e-11eb-a3d0-06b4694bee2a/members/embedded/1.3s/add" class="emailoctopus-form form bound" data-message-bot-submission-error="This doesn't look like a human submission." data-message-consent-required="Please check the checkbox to indicate your consent." data-message-invalid-email-address="Your email address looks incorrect, please try again." data-message-invalid-parameters-error="This form has missing or invalid fields." data-message-missing-email-address="Your email address is required." data-message-success="Thanks for subscribing!" data-message-unknown-error="Sorry, an unknown error has occurred. Please try again later." data-sitekey="6LdYsmsUAAAAAPXVTt-ovRsPIJ_IVhvYBBhGvRV6" data-widget-id="0" method="post">
# <p class="emailoctopus-success-message"></p>
# <p class="emailoctopus-error-message"></p>
# <input name="successRedirectUrl" type="hidden" value="https://devtomanager.com/thank-you/"/>
# <div class="input-group mb-2">
# <div class="input-group-prepend">
# <div class="input-group-text">
# <i class="icon-mail"></i>
# </div>
# </div>
# <input class="form-control" id="field_0" name="field_0" placeholder="email@example.com" required="" type="email"/>
# <div class="input-group-append">
# <button class="btn btn btn-dark" type="submit">
#                                     Join!
#                                 </button>
# </div>
# </div>
# <div class="emailoctopus-form-row-consent custom-control custom-switch">
# <input class="custom-control-input" id="consent" name="consent" required="" type="checkbox"/>
# <label class="custom-control-label" for="consent">
#                                 Yes, sign me up!
#                             </label>
# </div>
# <div aria-hidden="true" class="emailoctopus-form-row-hp d-none">
# <input autocomplete="nope" name="hpc4b27b6e-eb38-11e9-be00-06b4694bee2a" tabindex="-1" type="text"/>
# </div>
# <div class="g-recaptcha" data-sitekey="6LdYsmsUAAAAAPXVTt-ovRsPIJ_IVhvYBBhGvRV6" data-size="invisible" data-theme="light" data-type="image"><div class="grecaptcha-badge" data-style="bottomright" style="width: 256px; height: 60px; display: block; transition: right 0.3s ease 0s; position: fixed; bottom: 14px; right: -186px; box-shadow: gray 0px 0px 5px; border-radius: 2px; overflow: hidden;"><div class="grecaptcha-logo"><iframe frameborder="0" height="60" name="a-m88ef5l50ehe" role="presentation" sandbox="allow-forms allow-popups allow-same-origin allow-scripts allow-top-navigation allow-modals allow-popups-to-escape-sandbox" scrolling="no" src="https://www.google.com/recaptcha/api2/anchor?ar=1&amp;k=6LdYsmsUAAAAAPXVTt-ovRsPIJ_IVhvYBBhGvRV6&amp;co=aHR0cHM6Ly9kZXZ0b21hbmFnZXIuY29tOjQ0Mw..&amp;hl=en&amp;type=image&amp;v=_exWVY_hlNJJl2Abm8pI9i1L&amp;theme=light&amp;size=invisible&amp;cb=jhfjt1dovfq4" title="reCAPTCHA" width="256"></iframe></div><div class="grecaptcha-error"></div><textarea class="g-recaptcha-response" id="g-recaptcha-response" name="g-recaptcha-response" style="width: 250px; height: 40px; border: 1px solid rgb(193, 193, 193); margin: 10px 25px; padding: 0px; resize: none; display: none;"></textarea></div><iframe style="display: none;"></iframe></div></form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container border-top">
# <div class="row mt-3 mb-3">
# <div class="col">
#             © Developer to Manager 2018 - 2021
#
#             <a class="btn" href="https://twitter.com/devtomanager" target="_blank">
# <i class="icon-logo-twitter"></i>
# </a>
# <a class="btn" href="https://www.linkedin.com/company/developer-to-manager" target="_blank">
# <i class="icon-logo-linkedin"></i>
# </a>
# </div>
# <div class="col text-right">
# <span>Crafted with ♥️ in Munich</span>
# </div>
# </div>
# </div>
# <script async="" crossorigin="anonymous" integrity="sha384-0ekdM7lV68sbOr8s62kW4bKzV9c9AvM3TResBrO9+nRRWySSYhcWJaLDjqUe69Or" src="https://www.gstatic.com/recaptcha/releases/_exWVY_hlNJJl2Abm8pI9i1L/recaptcha__en.js" type="text/javascript"></script><script async="" data-domain="devtomanager.com" src="https://plausible.io/js/plausible.js">
# </script>
# <script async="" src="/static/js/app.js"></script>
# <script async="" src="https://emailoctopus.com/bundles/emailoctopuslist/js/1.6/form-recaptcha.js"></script>
# <script async="" src="https://emailoctopus.com/bundles/emailoctopuslist/js/1.6/form-embed.js"></script>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js?onload=onGoogleRecaptchaLoaded&amp;render=explicit" type="text/javascript"></script><div style="visibility: hidden; position: absolute; width: 100%; top: -10000px; left: 0px; right: 0px; transition: visibility 0s linear 0.3s, opacity 0.3s linear 0s; opacity: 0;"><div style="width: 100%; height: 100%; position: fixed; top: 0px; left: 0px; z-index: 2000000000; background-color: rgb(255, 255, 255); opacity: 0.5;"></div><div style="margin: 0px auto; top: 0px; left: 0px; right: 0px; position: absolute; border: 1px solid rgb(204, 204, 204); z-index: 2000000000; background-color: rgb(255, 255, 255); overflow: hidden;"><iframe frameborder="0" name="c-m88ef5l50ehe" sandbox="allow-forms allow-popups allow-same-origin allow-scripts allow-top-navigation allow-modals allow-popups-to-escape-sandbox" scrolling="no" src="https://www.google.com/recaptcha/api2/bframe?hl=en&amp;v=_exWVY_hlNJJl2Abm8pI9i1L&amp;k=6LdYsmsUAAAAAPXVTt-ovRsPIJ_IVhvYBBhGvRV6" style="width: 100%; height: 100%;" title="recaptcha challenge expires in two minutes"></iframe></div></div></body></html>

# %%
soup.title.text.strip()
# Out:
# 'Interviews with Software Managers | Developer to Manager'

# %% [markdown]
# ### Step7:- Extracting the Eployee Names from the Page using select method

# %%
emp_name = [i.text.strip().split(',')[0] for i in soup.select('h5.card-title')]
emp_name
# Out:
# ['Aviv Ben-Yosef', 'Anand Safi', 'Shawn Axsom', 'Kevin Doyle', 'Arnab Sen']

# %% [markdown]
# ### Step8:- Extracting the Eployee job role from the Page using select method

# %%
lst = [i.text.strip().split(',')[1] for i in soup.select('h5.card-title')]
lst
# Out:
# [' Tech Executive Consultant',
#  ' Engineering Manager at Mark43',
#  ' Senior Engineering Manager at Docker',
#  ' CTO at patientMpower',
#  ' Technical Delivery Manager at AKQA']

# %%
job_position = []
for i in lst:
    job_position.append(i.split('at')[0].strip(' '))

# %%
job_position
# Out:
# ['Tech Executive Consultant',
#  'Engineering Manager',
#  'Senior Engineering Manager',
#  'CTO',
#  'Technical Delivery Manager']

# %% [markdown]
# ### Step9:- Extracting the Eployee working Company from the Page

# %%
working = []
for i in lst:
    try:
        working.append(i.split('at ')[1].strip(' '))
    except:
        working.append(np.nan)

# %%
working
# Out:
# [nan, 'Mark43', 'Docker', 'patientMpower', 'AKQA']

# %% [markdown]
# ### Step10:- Extracting the Quotes,date and tags from the Page using select method

# %%
quote = [i.text.strip() for i in soup.select('p.card-text')][0::2]
quote
# Out:
# ['“I want to set up managers to succeed, no matter how much background they’ve already got.”',
#  '“I very well understand where my interests lie, which is being an enabler first and then a creator rather than being a creator/ maker 100%.”',
#  '“Your focus (and challenges) grows from your direct reports, to teams, to departments, executives, and then external customers and partnerships.”',
#  '“If I can provide enough direction to allow people to focus on the jobs they’ll do better than I ever could, everybody wins.”',
#  '“The switch to management can be highly rewarding and provide a level of independence, authority, and interactivity that a pure software engineering role may not offer.”']

# %%
 date = [i.text.strip().split('\n')[0] for i in soup.select('p.card-text')][1::2]
 date
# Out:
# ['August 16, 2021',
#  'July 19, 2021',
#  'July 05, 2021',
#  'June 21, 2021',
#  'May 10, 2021']

# %%
tags = [i.text.strip().split()[4:] for i in soup.select('p.card-text')][1::2]
tags
# Out:
# [['#coaching', '#consulting'],
#  ['#coaching', '#frontend', '#full-stack', '#public-safety'],
#  ['#backend', '#coaching', '#information-systems', '#web'],
#  ['#full-stack', '#health-tech'],
#  ['#consulting', '#digital-marketing', '#e-commerce', '#product']]

# %% [markdown]
# ### Step11: Reusable Code for single page to extract the data

# %%
def Interviews():
    emp_name = [i.text.strip().split(',')[0] for i in soup.select('h5.card-title')]
    lst = [i.text.strip().split(',')[1] for i in soup.select('h5.card-title')]
    job_position = []
    for i in lst:
        job_position.append(i.split('at')[0].strip(' '))
    working = []
    for i in lst:
        try:
            working.append(i.split('at ')[1].strip(' '))
        except:
            working.append(np.nan)
    quote = [i.text.strip() for i in soup.select('p.card-text')][0::2]
    date = [i.text.strip().split('\n')[0] for i in soup.select('p.card-text')][1::2]
    tags = [i.text.strip().split()[4:] for i in soup.select('p.card-text')][1::2]
    return pd.DataFrame({'Employee Name':emp_name,'Job Position':job_position,'Working':working,'Interview quote':quote,'Date':date,'Tags':tags})

# %% [markdown]
# ### Step11: Reusable Code for multiple pages by using single page reusable code to extract the data

# %%
tables=[]
for i in tqdm(range(1,6)):
    url_pages=url.format(i)
    browser.get(url_pages)
    time.sleep(5)
    html = browser.page_source
    soup = BeautifulSoup(html,'html.parser')
    tables.append(Interviews())
# Out:
# 100%|██████████| 5/5 [00:30<00:00,  6.20s/it]

# %% [markdown]
# ### Step12: Concating the tables data which extracted from multiple pages

# %%
interview = pd.concat(tables,axis=0)
interview
# Out:
#     Employee Name                Job Position        Working  \
# 0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1      Anand Safi         Engineering Manager         Mark43
# 2     Shawn Axsom  Senior Engineering Manager         Docker
# 3     Kevin Doyle                         CTO  patientMpower
# 4       Arnab Sen  Technical Delivery Manager           AKQA
# 0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1      Anand Safi         Engineering Manager         Mark43
# 2     Shawn Axsom  Senior Engineering Manager         Docker
# 3     Kevin Doyle                         CTO  patientMpower
# 4       Arnab Sen  Technical Delivery Manager           AKQA
# 0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1      Anand Safi         Engineering Manager         Mark43
# 2     Shawn Axsom  Senior Engineering Manager         Docker
# 3     Kevin Doyle                         CTO  patientMpower
# 4       Arnab Sen  Technical Delivery Manager           AKQA
# 0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1      Anand Safi         Engineering Manager         Mark43
# 2     Shawn Axsom  Senior Engineering Manager         Docker
# 3     Kevin Doyle                         CTO  patientMpower
# 4       Arnab Sen  Technical Delivery Manager           AKQA
# 0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1      Anand Safi         Engineering Manager         Mark43
# 2     Shawn Axsom  Senior Engineering Manager         Docker
# 3     Kevin Doyle                         CTO  patientMpower
# 4       Arnab Sen  Technical Delivery Manager           AKQA
#
#                                      Interview quote             Date  \
# 0  “I want to set up managers to succeed, no matt...  August 16, 2021
# 1  “I very well understand where my interests lie...    July 19, 2021
# 2  “Your focus (and challenges) grows from your d...    July 05, 2021
# 3  “If I can provide enough direction to allow pe...    June 21, 2021
# 4  “The switch to management can be highly reward...     May 10, 2021
# 0  “I want to set up managers to succeed, no matt...  August 16, 2021
# 1  “I very well understand where my interests lie...    July 19, 2021
# 2  “Your focus (and challenges) grows from your d...    July 05, 2021
# 3  “If I can provide enough direction to allow pe...    June 21, 2021
# 4  “The switch to management can be highly reward...     May 10, 2021
# 0  “I want to set up managers to succeed, no matt...  August 16, 2021
# 1  “I very well understand where my interests lie...    July 19, 2021
# 2  “Your focus (and challenges) grows from your d...    July 05, 2021
# 3  “If I can provide enough direction to allow pe...    June 21, 2021
# 4  “The switch to management can be highly reward...     May 10, 2021
# 0  “I want to set up managers to succeed, no matt...  August 16, 2021
# 1  “I very well understand where my interests lie...    July 19, 2021
# 2  “Your focus (and challenges) grows from your d...    July 05, 2021
# 3  “If I can provide enough direction to allow pe...    June 21, 2021
# 4  “The switch to management can be highly reward...     May 10, 2021
# 0  “I want to set up managers to succeed, no matt...  August 16, 2021
# 1  “I very well understand where my interests lie...    July 19, 2021
# 2  “Your focus (and challenges) grows from your d...    July 05, 2021
# 3  “If I can provide enough direction to allow pe...    June 21, 2021
# 4  “The switch to management can be highly reward...     May 10, 2021
#
#                                                 Tags
# 0                           [#coaching, #consulting]
# 1  [#coaching, #frontend, #full-stack, #public-sa...
# 2  [#backend, #coaching, #information-systems, #web]
# 3                        [#full-stack, #health-tech]
# 4  [#consulting, #digital-marketing, #e-commerce,...
# 0                           [#coaching, #consulting]
# 1  [#coaching, #frontend, #full-stack, #public-sa...
# 2  [#backend, #coaching, #information-systems, #web]
# 3                        [#full-stack, #health-tech]
# 4  [#consulting, #digital-marketing, #e-commerce,...
# 0                           [#coaching, #consulting]
# 1  [#coaching, #frontend, #full-stack, #public-sa...
# 2  [#backend, #coaching, #information-systems, #web]
# 3                        [#full-stack, #health-tech]
# 4  [#consulting, #digital-marketing, #e-commerce,...
# 0                           [#coaching, #consulting]
# 1  [#coaching, #frontend, #full-stack, #public-sa...
# 2  [#backend, #coaching, #information-systems, #web]
# 3                        [#full-stack, #health-tech]
# 4  [#consulting, #digital-marketing, #e-commerce,...
# 0                           [#coaching, #consulting]
# 1  [#coaching, #frontend, #full-stack, #public-sa...
# 2  [#backend, #coaching, #information-systems, #web]
# 3                        [#full-stack, #health-tech]
# 4  [#consulting, #digital-marketing, #e-commerce,...

# %% [markdown]
# ### Step13: Converting and saving the extracted table in to csv_file

# %%
interview.to_csv('interview.csv')

# %% [markdown]
# ### Step14: Checking the saved csv_file, filtering and modifing it to proper format

# %%
df = pd.read_csv('interview.csv')
df
# Out:
#     Unnamed: 0   Employee Name                Job Position        Working  \
# 0            0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1            1      Anand Safi         Engineering Manager         Mark43
# 2            2     Shawn Axsom  Senior Engineering Manager         Docker
# 3            3     Kevin Doyle                         CTO  patientMpower
# 4            4       Arnab Sen  Technical Delivery Manager           AKQA
# 5            0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 6            1      Anand Safi         Engineering Manager         Mark43
# 7            2     Shawn Axsom  Senior Engineering Manager         Docker
# 8            3     Kevin Doyle                         CTO  patientMpower
# 9            4       Arnab Sen  Technical Delivery Manager           AKQA
# 10           0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 11           1      Anand Safi         Engineering Manager         Mark43
# 12           2     Shawn Axsom  Senior Engineering Manager         Docker
# 13           3     Kevin Doyle                         CTO  patientMpower
# 14           4       Arnab Sen  Technical Delivery Manager           AKQA
# 15           0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 16           1      Anand Safi         Engineering Manager         Mark43
# 17           2     Shawn Axsom  Senior Engineering Manager         Docker
# 18           3     Kevin Doyle                         CTO  patientMpower
# 19           4       Arnab Sen  Technical Delivery Manager           AKQA
# 20           0  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 21           1      Anand Safi         Engineering Manager         Mark43
# 22           2     Shawn Axsom  Senior Engineering Manager         Docker
# 23           3     Kevin Doyle                         CTO  patientMpower
# 24           4       Arnab Sen  Technical Delivery Manager           AKQA
#
#                                       Interview quote             Date  \
# 0   “I want to set up managers to succeed, no matt...  August 16, 2021
# 1   “I very well understand where my interests lie...    July 19, 2021
# 2   “Your focus (and challenges) grows from your d...    July 05, 2021
# 3   “If I can provide enough direction to allow pe...    June 21, 2021
# 4   “The switch to management can be highly reward...     May 10, 2021
# 5   “I want to set up managers to succeed, no matt...  August 16, 2021
# 6   “I very well understand where my interests lie...    July 19, 2021
# 7   “Your focus (and challenges) grows from your d...    July 05, 2021
# 8   “If I can provide enough direction to allow pe...    June 21, 2021
# 9   “The switch to management can be highly reward...     May 10, 2021
# 10  “I want to set up managers to succeed, no matt...  August 16, 2021
# 11  “I very well understand where my interests lie...    July 19, 2021
# 12  “Your focus (and challenges) grows from your d...    July 05, 2021
# 13  “If I can provide enough direction to allow pe...    June 21, 2021
# 14  “The switch to management can be highly reward...     May 10, 2021
# 15  “I want to set up managers to succeed, no matt...  August 16, 2021
# 16  “I very well understand where my interests lie...    July 19, 2021
# 17  “Your focus (and challenges) grows from your d...    July 05, 2021
# 18  “If I can provide enough direction to allow pe...    June 21, 2021
# 19  “The switch to management can be highly reward...     May 10, 2021
# 20  “I want to set up managers to succeed, no matt...  August 16, 2021
# 21  “I very well understand where my interests lie...    July 19, 2021
# 22  “Your focus (and challenges) grows from your d...    July 05, 2021
# 23  “If I can provide enough direction to allow pe...    June 21, 2021
# 24  “The switch to management can be highly reward...     May 10, 2021
#
#                                                  Tags
# 0                        ['#coaching', '#consulting']
# 1   ['#coaching', '#frontend', '#full-stack', '#pu...
# 2   ['#backend', '#coaching', '#information-system...
# 3                     ['#full-stack', '#health-tech']
# 4   ['#consulting', '#digital-marketing', '#e-comm...
# 5                        ['#coaching', '#consulting']
# 6   ['#coaching', '#frontend', '#full-stack', '#pu...
# 7   ['#backend', '#coaching', '#information-system...
# 8                     ['#full-stack', '#health-tech']
# 9   ['#consulting', '#digital-marketing', '#e-comm...
# 10                       ['#coaching', '#consulting']
# 11  ['#coaching', '#frontend', '#full-stack', '#pu...
# 12  ['#backend', '#coaching', '#information-system...
# 13                    ['#full-stack', '#health-tech']
# 14  ['#consulting', '#digital-marketing', '#e-comm...
# 15                       ['#coaching', '#consulting']
# 16  ['#coaching', '#frontend', '#full-stack', '#pu...
# 17  ['#backend', '#coaching', '#information-system...
# 18                    ['#full-stack', '#health-tech']
# 19  ['#consulting', '#digital-marketing', '#e-comm...
# 20                       ['#coaching', '#consulting']
# 21  ['#coaching', '#frontend', '#full-stack', '#pu...
# 22  ['#backend', '#coaching', '#information-system...
# 23                    ['#full-stack', '#health-tech']
# 24  ['#consulting', '#digital-marketing', '#e-comm...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#      Employee Name                Job Position        Working  \
# 0   Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1       Anand Safi         Engineering Manager         Mark43
# 2      Shawn Axsom  Senior Engineering Manager         Docker
# 3      Kevin Doyle                         CTO  patientMpower
# 4        Arnab Sen  Technical Delivery Manager           AKQA
# 5   Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 6       Anand Safi         Engineering Manager         Mark43
# 7      Shawn Axsom  Senior Engineering Manager         Docker
# 8      Kevin Doyle                         CTO  patientMpower
# 9        Arnab Sen  Technical Delivery Manager           AKQA
# 10  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 11      Anand Safi         Engineering Manager         Mark43
# 12     Shawn Axsom  Senior Engineering Manager         Docker
# 13     Kevin Doyle                         CTO  patientMpower
# 14       Arnab Sen  Technical Delivery Manager           AKQA
# 15  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 16      Anand Safi         Engineering Manager         Mark43
# 17     Shawn Axsom  Senior Engineering Manager         Docker
# 18     Kevin Doyle                         CTO  patientMpower
# 19       Arnab Sen  Technical Delivery Manager           AKQA
# 20  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 21      Anand Safi         Engineering Manager         Mark43
# 22     Shawn Axsom  Senior Engineering Manager         Docker
# 23     Kevin Doyle                         CTO  patientMpower
# 24       Arnab Sen  Technical Delivery Manager           AKQA
#
#                                       Interview quote             Date  \
# 0   “I want to set up managers to succeed, no matt...  August 16, 2021
# 1   “I very well understand where my interests lie...    July 19, 2021
# 2   “Your focus (and challenges) grows from your d...    July 05, 2021
# 3   “If I can provide enough direction to allow pe...    June 21, 2021
# 4   “The switch to management can be highly reward...     May 10, 2021
# 5   “I want to set up managers to succeed, no matt...  August 16, 2021
# 6   “I very well understand where my interests lie...    July 19, 2021
# 7   “Your focus (and challenges) grows from your d...    July 05, 2021
# 8   “If I can provide enough direction to allow pe...    June 21, 2021
# 9   “The switch to management can be highly reward...     May 10, 2021
# 10  “I want to set up managers to succeed, no matt...  August 16, 2021
# 11  “I very well understand where my interests lie...    July 19, 2021
# 12  “Your focus (and challenges) grows from your d...    July 05, 2021
# 13  “If I can provide enough direction to allow pe...    June 21, 2021
# 14  “The switch to management can be highly reward...     May 10, 2021
# 15  “I want to set up managers to succeed, no matt...  August 16, 2021
# 16  “I very well understand where my interests lie...    July 19, 2021
# 17  “Your focus (and challenges) grows from your d...    July 05, 2021
# 18  “If I can provide enough direction to allow pe...    June 21, 2021
# 19  “The switch to management can be highly reward...     May 10, 2021
# 20  “I want to set up managers to succeed, no matt...  August 16, 2021
# 21  “I very well understand where my interests lie...    July 19, 2021
# 22  “Your focus (and challenges) grows from your d...    July 05, 2021
# 23  “If I can provide enough direction to allow pe...    June 21, 2021
# 24  “The switch to management can be highly reward...     May 10, 2021
#
#                                                  Tags
# 0                        ['#coaching', '#consulting']
# 1   ['#coaching', '#frontend', '#full-stack', '#pu...
# 2   ['#backend', '#coaching', '#information-system...
# 3                     ['#full-stack', '#health-tech']
# 4   ['#consulting', '#digital-marketing', '#e-comm...
# 5                        ['#coaching', '#consulting']
# 6   ['#coaching', '#frontend', '#full-stack', '#pu...
# 7   ['#backend', '#coaching', '#information-system...
# 8                     ['#full-stack', '#health-tech']
# 9   ['#consulting', '#digital-marketing', '#e-comm...
# 10                       ['#coaching', '#consulting']
# 11  ['#coaching', '#frontend', '#full-stack', '#pu...
# 12  ['#backend', '#coaching', '#information-system...
# 13                    ['#full-stack', '#health-tech']
# 14  ['#consulting', '#digital-marketing', '#e-comm...
# 15                       ['#coaching', '#consulting']
# 16  ['#coaching', '#frontend', '#full-stack', '#pu...
# 17  ['#backend', '#coaching', '#information-system...
# 18                    ['#full-stack', '#health-tech']
# 19  ['#consulting', '#digital-marketing', '#e-comm...
# 20                       ['#coaching', '#consulting']
# 21  ['#coaching', '#frontend', '#full-stack', '#pu...
# 22  ['#backend', '#coaching', '#information-system...
# 23                    ['#full-stack', '#health-tech']
# 24  ['#consulting', '#digital-marketing', '#e-comm...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Employee Name    25 non-null     object
#  1   Job Position     25 non-null     object
#  2   Working          20 non-null     object
#  3   Interview quote  25 non-null     object
#  4   Date             25 non-null     object
#  5   Tags             25 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])
df
# Out:
#      Employee Name                Job Position        Working  \
# 0   Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1       Anand Safi         Engineering Manager         Mark43
# 2      Shawn Axsom  Senior Engineering Manager         Docker
# 3      Kevin Doyle                         CTO  patientMpower
# 4        Arnab Sen  Technical Delivery Manager           AKQA
# 5   Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 6       Anand Safi         Engineering Manager         Mark43
# 7      Shawn Axsom  Senior Engineering Manager         Docker
# 8      Kevin Doyle                         CTO  patientMpower
# 9        Arnab Sen  Technical Delivery Manager           AKQA
# 10  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 11      Anand Safi         Engineering Manager         Mark43
# 12     Shawn Axsom  Senior Engineering Manager         Docker
# 13     Kevin Doyle                         CTO  patientMpower
# 14       Arnab Sen  Technical Delivery Manager           AKQA
# 15  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 16      Anand Safi         Engineering Manager         Mark43
# 17     Shawn Axsom  Senior Engineering Manager         Docker
# 18     Kevin Doyle                         CTO  patientMpower
# 19       Arnab Sen  Technical Delivery Manager           AKQA
# 20  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 21      Anand Safi         Engineering Manager         Mark43
# 22     Shawn Axsom  Senior Engineering Manager         Docker
# 23     Kevin Doyle                         CTO  patientMpower
# 24       Arnab Sen  Technical Delivery Manager           AKQA
#
#                                       Interview quote       Date  \
# 0   “I want to set up managers to succeed, no matt... 2021-08-16
# 1   “I very well understand where my interests lie... 2021-07-19
# 2   “Your focus (and challenges) grows from your d... 2021-07-05
# 3   “If I can provide enough direction to allow pe... 2021-06-21
# 4   “The switch to management can be highly reward... 2021-05-10
# 5   “I want to set up managers to succeed, no matt... 2021-08-16
# 6   “I very well understand where my interests lie... 2021-07-19
# 7   “Your focus (and challenges) grows from your d... 2021-07-05
# 8   “If I can provide enough direction to allow pe... 2021-06-21
# 9   “The switch to management can be highly reward... 2021-05-10
# 10  “I want to set up managers to succeed, no matt... 2021-08-16
# 11  “I very well understand where my interests lie... 2021-07-19
# 12  “Your focus (and challenges) grows from your d... 2021-07-05
# 13  “If I can provide enough direction to allow pe... 2021-06-21
# 14  “The switch to management can be highly reward... 2021-05-10
# 15  “I want to set up managers to succeed, no matt... 2021-08-16
# 16  “I very well understand where my interests lie... 2021-07-19
# 17  “Your focus (and challenges) grows from your d... 2021-07-05
# 18  “If I can provide enough direction to allow pe... 2021-06-21
# 19  “The switch to management can be highly reward... 2021-05-10
# 20  “I want to set up managers to succeed, no matt... 2021-08-16
# 21  “I very well understand where my interests lie... 2021-07-19
# 22  “Your focus (and challenges) grows from your d... 2021-07-05
# 23  “If I can provide enough direction to allow pe... 2021-06-21
# 24  “The switch to management can be highly reward... 2021-05-10
#
#                                                  Tags
# 0                        ['#coaching', '#consulting']
# 1   ['#coaching', '#frontend', '#full-stack', '#pu...
# 2   ['#backend', '#coaching', '#information-system...
# 3                     ['#full-stack', '#health-tech']
# 4   ['#consulting', '#digital-marketing', '#e-comm...
# 5                        ['#coaching', '#consulting']
# 6   ['#coaching', '#frontend', '#full-stack', '#pu...
# 7   ['#backend', '#coaching', '#information-system...
# 8                     ['#full-stack', '#health-tech']
# 9   ['#consulting', '#digital-marketing', '#e-comm...
# 10                       ['#coaching', '#consulting']
# 11  ['#coaching', '#frontend', '#full-stack', '#pu...
# 12  ['#backend', '#coaching', '#information-system...
# 13                    ['#full-stack', '#health-tech']
# 14  ['#consulting', '#digital-marketing', '#e-comm...
# 15                       ['#coaching', '#consulting']
# 16  ['#coaching', '#frontend', '#full-stack', '#pu...
# 17  ['#backend', '#coaching', '#information-system...
# 18                    ['#full-stack', '#health-tech']
# 19  ['#consulting', '#digital-marketing', '#e-comm...
# 20                       ['#coaching', '#consulting']
# 21  ['#coaching', '#frontend', '#full-stack', '#pu...
# 22  ['#backend', '#coaching', '#information-system...
# 23                    ['#full-stack', '#health-tech']
# 24  ['#consulting', '#digital-marketing', '#e-comm...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Employee Name    25 non-null     object
#  1   Job Position     25 non-null     object
#  2   Working          20 non-null     object
#  3   Interview quote  25 non-null     object
#  4   Date             25 non-null     datetime64[ns]
#  5   Tags             25 non-null     object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 1.3+ KB

# %%
df['Tags']=df['Tags'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Employee Name    25 non-null     object
#  1   Job Position     25 non-null     object
#  2   Working          20 non-null     object
#  3   Interview quote  25 non-null     object
#  4   Date             25 non-null     datetime64[ns]
#  5   Tags             25 non-null     category
# dtypes: category(1), datetime64[ns](1), object(4)
# memory usage: 1.3+ KB

# %% [markdown]
# ### Step15:- Saving the updated table as csv_file

# %%
df.to_csv('Interviews.csv',index=False)

# %%
df1=pd.read_csv('Interviews.csv')
df1
# Out:
#      Employee Name                Job Position        Working  \
# 0   Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 1       Anand Safi         Engineering Manager         Mark43
# 2      Shawn Axsom  Senior Engineering Manager         Docker
# 3      Kevin Doyle                         CTO  patientMpower
# 4        Arnab Sen  Technical Delivery Manager           AKQA
# 5   Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 6       Anand Safi         Engineering Manager         Mark43
# 7      Shawn Axsom  Senior Engineering Manager         Docker
# 8      Kevin Doyle                         CTO  patientMpower
# 9        Arnab Sen  Technical Delivery Manager           AKQA
# 10  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 11      Anand Safi         Engineering Manager         Mark43
# 12     Shawn Axsom  Senior Engineering Manager         Docker
# 13     Kevin Doyle                         CTO  patientMpower
# 14       Arnab Sen  Technical Delivery Manager           AKQA
# 15  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 16      Anand Safi         Engineering Manager         Mark43
# 17     Shawn Axsom  Senior Engineering Manager         Docker
# 18     Kevin Doyle                         CTO  patientMpower
# 19       Arnab Sen  Technical Delivery Manager           AKQA
# 20  Aviv Ben-Yosef   Tech Executive Consultant            NaN
# 21      Anand Safi         Engineering Manager         Mark43
# 22     Shawn Axsom  Senior Engineering Manager         Docker
# 23     Kevin Doyle                         CTO  patientMpower
# 24       Arnab Sen  Technical Delivery Manager           AKQA
#
#                                       Interview quote        Date  \
# 0   “I want to set up managers to succeed, no matt...  2021-08-16
# 1   “I very well understand where my interests lie...  2021-07-19
# 2   “Your focus (and challenges) grows from your d...  2021-07-05
# 3   “If I can provide enough direction to allow pe...  2021-06-21
# 4   “The switch to management can be highly reward...  2021-05-10
# 5   “I want to set up managers to succeed, no matt...  2021-08-16
# 6   “I very well understand where my interests lie...  2021-07-19
# 7   “Your focus (and challenges) grows from your d...  2021-07-05
# 8   “If I can provide enough direction to allow pe...  2021-06-21
# 9   “The switch to management can be highly reward...  2021-05-10
# 10  “I want to set up managers to succeed, no matt...  2021-08-16
# 11  “I very well understand where my interests lie...  2021-07-19
# 12  “Your focus (and challenges) grows from your d...  2021-07-05
# 13  “If I can provide enough direction to allow pe...  2021-06-21
# 14  “The switch to management can be highly reward...  2021-05-10
# 15  “I want to set up managers to succeed, no matt...  2021-08-16
# 16  “I very well understand where my interests lie...  2021-07-19
# 17  “Your focus (and challenges) grows from your d...  2021-07-05
# 18  “If I can provide enough direction to allow pe...  2021-06-21
# 19  “The switch to management can be highly reward...  2021-05-10
# 20  “I want to set up managers to succeed, no matt...  2021-08-16
# 21  “I very well understand where my interests lie...  2021-07-19
# 22  “Your focus (and challenges) grows from your d...  2021-07-05
# 23  “If I can provide enough direction to allow pe...  2021-06-21
# 24  “The switch to management can be highly reward...  2021-05-10
#
#                                                  Tags
# 0                        ['#coaching', '#consulting']
# 1   ['#coaching', '#frontend', '#full-stack', '#pu...
# 2   ['#backend', '#coaching', '#information-system...
# 3                     ['#full-stack', '#health-tech']
# 4   ['#consulting', '#digital-marketing', '#e-comm...
# 5                        ['#coaching', '#consulting']
# 6   ['#coaching', '#frontend', '#full-stack', '#pu...
# 7   ['#backend', '#coaching', '#information-system...
# 8                     ['#full-stack', '#health-tech']
# 9   ['#consulting', '#digital-marketing', '#e-comm...
# 10                       ['#coaching', '#consulting']
# 11  ['#coaching', '#frontend', '#full-stack', '#pu...
# 12  ['#backend', '#coaching', '#information-system...
# 13                    ['#full-stack', '#health-tech']
# 14  ['#consulting', '#digital-marketing', '#e-comm...
# 15                       ['#coaching', '#consulting']
# 16  ['#coaching', '#frontend', '#full-stack', '#pu...
# 17  ['#backend', '#coaching', '#information-system...
# 18                    ['#full-stack', '#health-tech']
# 19  ['#consulting', '#digital-marketing', '#e-comm...
# 20                       ['#coaching', '#consulting']
# 21  ['#coaching', '#frontend', '#full-stack', '#pu...
# 22  ['#backend', '#coaching', '#information-system...
# 23                    ['#full-stack', '#health-tech']
# 24  ['#consulting', '#digital-marketing', '#e-comm...
